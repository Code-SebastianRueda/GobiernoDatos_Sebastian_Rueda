# %% [markdown]
# <a href="https://colab.research.google.com/github/Code-SebastianRueda/GobiernoDatos_Sebastian_Rueda/blob/main/Inforgrafia_Colombia_Vs_Mexico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Infografia Colombia VS Mexico
# ![Inforgrafia Colombia VS Mexico.drawio.png](data:image/png;base64,...)
#
#
# Para mas infromacion y detalle de la infografia consulte el siguiente enlace: https://drive.google.com/file/d/1O1tw-fkuiybOLzoJw6vIkpw1KHkVERX2/view?usp=sharing
