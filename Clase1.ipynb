# %% [markdown]
# <a href="https://colab.research.google.com/github/Code-SebastianRueda/GobiernoDatos_Sebastian_Rueda/blob/main/Clase1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Clase 1: Modelo de bibliografia

# %% [markdown]
# ![imagen_2024-08-14_194511642.png](data:image/png;base64,...)
